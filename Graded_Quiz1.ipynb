# %%
# Import pandas and Read the csv file
import pandas as pd

url = 'https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'

df = pd.read_csv(url, encoding = 'latin-1')

df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# Question 1
df.groupby('Item')[ 'Y2015','Y2018'].sum() .loc['Wine']
# Out:
# <ipython-input-298-c6f632248ae0>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Item')[ 'Y2015','Y2018'].sum() .loc['Wine']
# Y2015    4251.81
# Y2018    4039.32
# Name: Wine, dtype: float64

# %%
# Question 2
'''Set is a data structure that is unordered'''
# Out:
# 'Set is a data structure that is unordered'

# %%
# Question 3

lst = [[35, 'Portugal', 94], [33, 'Argentina','93'], [30, 'Brasil', 92]]
col = ['Age', 'Nationality', 'Overall']

pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality Overall
# 1   35    Portugal      94
# 2   33   Argentina      93
# 3   30      Brasil      92

# %%
# Queston 4

df.groupby('Element')['Y2017'].sum() ['Processing']
# Out:
# 292836.0

# %%
# Question 5
MissingValue = df['Y2014'].isnull().sum()

MissingValuePercent = MissingValue * 100 / len(df)

print(MissingValue, '\n', round(MissingValuePercent, 3), '%' )
# Out:
# 1589
#  2.607 %

# %%
# Question 6
round(df['Y2017'].describe().iloc[1: 3], 2)
# Out:
# mean     140.92
# std     1671.86
# Name: Y2017, dtype: float64

# %%
# Question 7
y = [(2, 4), (7, 8), (1, 5, 9)]
x1 = y[1][1]
x2 = y[1][-1]

print(x1, '\n', x2)
# Out:
# 8
#  8

# %%
# Question 8
'''python inbuilt module is Math'''
# Out:
# 'python inbuilt module is Math'

# %%
# Question 9
df['Element Code']

df.groupby('Element Code')['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'].corr().min()
# Out:
# <ipython-input-306-b62c81422752>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Element Code')['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'].corr().min()
# Y2014   -0.086111
# Y2015    0.202471
# Y2016    0.202471
# Y2017    0.203159
# Y2018   -0.086111
# dtype: float64

# %%
# Question 10
df.groupby('Area')['Element', 'Y2015'].sum().loc['Madagascar']
# Out:
# <ipython-input-307-a65f5d9f1cf0>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Area')['Element', 'Y2015'].sum().loc['Madagascar']
# <ipython-input-307-a65f5d9f1cf0>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Area')['Element', 'Y2015'].sum().loc['Madagascar']
# Y2015    126674.9
# Name: Madagascar, dtype: float64

# %%
# Question 11
df.groupby('Area')[ 'Y2017'].sum()  #.max()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
# Question 12

''''''
df.iloc[ : ]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# Question 13
'''3 features and 100 observations'''
# Out:
# '3 features and 100 observations'

# %%
# Question 14
df['Area'].nunique()
# Out:
# 49

# %%
# Question 15
my_tuppy = (1, 2, 5, 8)
# my_tuppy[2] = 6 ; gives TypeError

# %%
# Question 16
df.groupby('Area')['Y2017'].sum().sort_values() #. iloc[6]
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
# Question 17
array = np.array([[94, 89, 63],
          [94, 92, 48],
          [92, 94, 56]] )

array[ :2, 1: ]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
# Question 18
df.groupby('Element')['Y2014', 'Y2015', 'Y2016', 'Y2017','Y2018'].sum() .loc['Stock Variation']
# Out:
# <ipython-input-315-9d58d4b97fcd>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Element')['Y2014', 'Y2015', 'Y2016', 'Y2017','Y2018'].sum() .loc['Stock Variation']
# Y2014    58749.83
# Y2015    34910.99
# Y2016    33140.12
# Y2017    54316.91
# Y2018    20577.91
# Name: Stock Variation, dtype: float64

# %%
# Question 19
df.shape
# Out:
# (60943, 12)

# %%
# Question 20
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'
